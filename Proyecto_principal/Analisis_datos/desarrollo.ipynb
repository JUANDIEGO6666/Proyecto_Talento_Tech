# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

"""
#1: Generar un DataFrame con los datos del fichero
#2: Hacer el tratamiento de los nulos
#3: Mostrar en pantallas las dimensiones del dataframe, el número de datos que contiene, los nombres de sus columnas y filas,
los tipos de datos de las columnas, las 10 primeras y las 10 últimas filas.
# 
"""
ruta= Path('Cambios_Todos')/'archivo.csv'
demog = pd.read_csv('C:/Users/User/Desktop/IA_pr2/Proyecto_Talento_Tech/archivo.csv')

print(demog.head())

print(demog.describe())

#Columnas
print(demog.columns)
# Out:
#     Año  Índice dedependencia  Índice deenvejecimiento  Índice deinfancia  \
# 0  1985             73.569557                 9.687815          36.222740
# 1  1986             72.452461                 9.844629          35.308765
# 2  1987             71.317497                10.054592          34.535152
# 3  1988             70.160576                10.398137          33.815468
# 4  1989             69.026817                11.059255          33.044563
#
#    Índice dejuventud  Índice de vejez  Población por área Urbana  \
# 0          32.243866         4.163074                     283479
# 1          32.107483         4.203105                     284194
# 2          31.863619         4.255428                     285550
# 3          31.484514         4.347024                     287408
# 4          30.911924         4.540338                     289587
#
#    Población Centros Poblados y Rural Disperso  Relación hombre-mujer  \
# ...

# %%
#Tratamiento de nulos no se hace necesario
print(demog.isnull().sum())
# Out:
# Año                                            0
# Índice dedependencia                           0
# Índice deenvejecimiento                        0
# Índice deinfancia                              0
# Índice dejuventud                              0
# Índice de vejez                                0
# Población por área Urbana                      0
# Población Centros Poblados y Rural Disperso    0
# Relación hombre-mujer                          0
# Población total-Hombres                        0
# Población total-Mujeres                        0
# Población Total                                0
# dtype: int64

# %%
plt.figure(figsize = (8,5))
plt.plot(demog["Año"], demog["Población Total"], color = "magenta")
plt.plot(demog["Año"], demog["Población por área Urbana"], color = "skyblue")
plt.plot(demog["Año"], demog["Población Centros Poblados y Rural Disperso"], color = "orange")
plt.title("Frecuencia de la edad de los pasajeros")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.legend(["Población Total",
            "Población Urbana",
            "Población Rural"])

plt.show()
